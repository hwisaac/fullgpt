# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

# OpenAI 모델 설정
chat = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.7,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()],
)

# 프로그래밍 언어에 대한 시를 생성하는 체인
poetry_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a poet specializing in writing poetry about programming languages."),
        ("human", "Write a short poem about the {language} programming language."),
    ]
)

poetry_chain = poetry_prompt | chat

# 시를 설명하는 체인
explanation_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert in literary analysis. You explain poetry in an insightful way."),
        ("human", "Explain the meaning and themes of the following poem:\n\n{poem}"),
    ]
)

explanation_chain = explanation_prompt | chat

# LCEL을 사용하여 두 체인 연결
final_chain = {"poem": poetry_chain} | explanation_chain

# 실행
def generate_poetry_and_explanation(language: str):
    response = final_chain.invoke({"language": language})
    return response

# 테스트 실행
print(generate_poetry_and_explanation("Python"))
# Out:
# In a world where syntax dances free,
# Python weaves its tapestry,
# Indentations mark the flow,
# A language where ideas grow.
#
# With elegance, it charms the mind,
# From simple scripts to code refined,
# Libraries vast, a treasure trove,
# In every line, creativity roves.
#
# From web to data, AI’s embrace,
# A gentle power, a warm embrace,
# In every byte, a story told,
# Python, the language, bright and bold.  This poem celebrates the programming language Python, using rich imagery and metaphor to convey both its technical aspects and its creative potential. The language of the poem itself reflects the flow and structure of coding, with each stanza contributing to a broader understanding of Python's significance in the modern world.
#
# ### Meaning:
#
# 1. **Syntax and Structure**: The opening lines, "In a world where syntax dances free," suggest a realm where the rules of coding are flexible and artistic. The mention of "Indentations mark the flow" refers to Python's unique syntax that relies on indentation to define code blocks, hinting at how structure can also be a form of expression.
#
# 2. **Creativity and Growth**: The phrase "A language where ideas grow" encapsulates the essence of programming as a creative endeavor. Python is portrayed not just as a tool for computation, but as a medium through which ideas can evolve and flourish.
#
# 3. **Elegance and Refinement**: The poem highlights Python's elegance, noting that it can handle everything from "simple scripts to code refined." This juxtaposition illustrates its versatility, making it accessible to beginners while also powerful enough for advanced applications.
#
# 4. **Treasure Trove of Libraries**: The reference to "Libraries vast, a treasure trove" emphasizes the rich ecosystem of pre-built code (libraries) available in Python that developers can utilize. This abundance allows for greater creativity and efficiency in coding.
#
# 5. **Applications and Impact**: The lines "From web to data, AI’s embrace" point to the diverse applications of Python, from web development to data science and artificial intelligence. This highlights the language's relevance in contemporary technology and its role in shaping future innovations.
#
# 6. **Storytelling through Code**: The concluding thoughts, "In every byte, a story told," suggest that every piece of code written in Python has a narrative, whether it's solving a problem, telling a story, or creating an experience. This reinforces the idea that programming is not merely technical work, but a form of communication and artistry.
#
# ### Themes:
#
# 1. **Creativity in Technology**: The poem embodies the theme of creativity within the technical realm. It suggests that programming, particularly with Python, is an artistic endeavor, akin to weaving a tapestry.
#
# 2. **Accessibility and Versatility**: Python is portrayed as both accessible for beginners and powerful for experts, reflecting the theme of inclusivity in technology. This makes programming more democratic, allowing a wider range of people to participate in coding.
#
# 3. **Interconnectedness of Ideas**: The poem underscores how programming languages like Python facilitate connections between different fields—web development, data analysis, and AI—highlighting the interdisciplinary nature of modern technology.
#
# 4. **Empowerment through Knowledge**: By emphasizing the “gentle power” of Python, the poem communicates a theme of empowerment. It suggests that knowledge of this language can enable individuals to create impactful work and tell their stories.
#
# In summary, this poem serves as both an ode to Python and a reflection on the broader implications of programming in the creative landscape, celebrating its beauty, versatility, and transformative potential.content='This poem celebrates the programming language Python, using rich imagery and metaphor to convey both its technical aspects and its creative potential. The language of the poem itself reflects the flow and structure of coding, with each stanza contributing to a broader understanding of Python\'s significance in the modern world.\n\n### Meaning:\n\n1. **Syntax and Structure**: The opening lines, "In a world where syntax dances free," suggest a realm where the rules of coding are flexible and artistic. The mention of "Indentations mark the flow" refers to Python\'s unique syntax that relies on indentation to define code blocks, hinting at how structure can also be a form of expression.\n\n2. **Creativity and Growth**: The phrase "A language where ideas grow" encapsulates the essence of programming as a creative endeavor. Python is portrayed not just as a tool for computation, but as a medium through which ideas can evolve and flourish.\n\n3. **Elegance and Refinement**: The poem highlights Python\'s elegance, noting that it can handle everything from "simple scripts to code refined." This juxtaposition illustrates its versatility, making it accessible to beginners while also powerful enough for advanced applications.\n\n4. **Treasure Trove of Libraries**: The reference to "Libraries vast, a treasure trove" emphasizes the rich ecosystem of pre-built code (libraries) available in Python that developers can utilize. This abundance allows for greater creativity and efficiency in coding.\n\n5. **Applications and Impact**: The lines "From web to data, AI’s embrace" point to the diverse applications of Python, from web development to data science and artificial intelligence. This highlights the language\'s relevance in contemporary technology and its role in shaping future innovations.\n\n6. **Storytelling through Code**: The concluding thoughts, "In every byte, a story told," suggest that every piece of code written in Python has a narrative, whether it\'s solving a problem, telling a story, or creating an experience. This reinforces the idea that programming is not merely technical work, but a form of communication and artistry.\n\n### Themes:\n\n1. **Creativity in Technology**: The poem embodies the theme of creativity within the technical realm. It suggests that programming, particularly with Python, is an artistic endeavor, akin to weaving a tapestry.\n\n2. **Accessibility and Versatility**: Python is portrayed as both accessible for beginners and powerful for experts, reflecting the theme of inclusivity in technology. This makes programming more democratic, allowing a wider range of people to participate in coding.\n\n3. **Interconnectedness of Ideas**: The poem underscores how programming languages like Python facilitate connections between different fields—web development, data analysis, and AI—highlighting the interdisciplinary nature of modern technology.\n\n4. **Empowerment through Knowledge**: By emphasizing the “gentle power” of Python, the poem communicates a theme of empowerment. It suggests that knowledge of this language can enable individuals to create impactful work and tell their stories.\n\nIn summary, this poem serves as both an ode to Python and a reflection on the broader implications of programming in the creative landscape, celebrating its beauty, versatility, and transformative potential.'
