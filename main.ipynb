# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.callbacks import StreamingStdOutCallbackHandler

# OpenAI 모델 설정
chat = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.7,
    streaming=True,
    callbacks=[StreamingStdOutCallbackHandler()],
)

# 프로그래밍 언어에 대한 시를 생성하는 체인
poetry_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are a poet specializing in writing poetry about programming languages."),
        ("human", "Write a short poem about the {language} programming language."),
    ]
)

poetry_chain = poetry_prompt | chat

# 시를 설명하는 체인
explanation_prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "You are an expert in literary analysis. You explain poetry in an insightful way."),
        ("human", "Explain the meaning and themes of the following poem:\n\n{poem}"),
    ]
)

explanation_chain = explanation_prompt | chat

# LCEL을 사용하여 두 체인 연결
final_chain = {"poem": poetry_chain} | explanation_chain

# 실행
def generate_poetry_and_explanation(language: str):
    response = final_chain.invoke({"language": language})
    return response

# 테스트 실행
print(generate_poetry_and_explanation("Python"))
# Out:
# That sounds great! Indian cuisine is diverse and flavorful. Here are a few popular dishes you might consider cooking, along with brief descriptions and recipes:
#
# ### 1. **Butter Chicken (Murgh Makhani)**
#
# **Ingredients:**
# - 500g chicken, cut into pieces
# - 1 cup yogurt
# - 2 tablespoons lemon juice
# - 2 teaspoons garam masala
# - 1 teaspoon turmeric
# - 1 teaspoon chili powder
# - 2 tablespoons butter
# - 1 onion, finely chopped
# - 2 cloves garlic, minced
# - 1-inch ginger, grated
# - 1 cup tomato puree
# - 1 cup cream
# - Salt to taste
# - Fresh cilantro for garnish
#
# **Instructions:**
# 1. Marinate the chicken in yogurt, lemon juice, garam masala, turmeric, and chili powder for at least 1 hour (or overnight).
# 2. In a pan, melt butter and sauté onions until golden. Add garlic and ginger, cooking for another minute.
# 3. Add the marinated chicken and cook until browned.
# 4. Stir in tomato puree and simmer for 15 minutes.
# 5. Add cream and salt, cooking for another 5 minutes.
# 6. Garnish with cilantro and serve with naan or rice.
#
# ### 2. **Chana Masala (Chickpea Curry)**
#
# **Ingredients:**
# - 2 cups canned chickpeas (or cooked from dried)
# - 1 onion, finely chopped
# - 2 tomatoes, chopped
# - 2 green chilies, slit
# - 1 teaspoon ginger-garlic paste
# - 1 teaspoon cumin seeds
# - 1 teaspoon coriander powder
# - 1 teaspoon cumin powder
# - 1 teaspoon garam masala
# - Salt to taste
# - Fresh cilantro for garnish
# - Oil for cooking
#
# **Instructions:**
# 1. Heat oil in a pan and add cumin seeds. Once they splutter, add onions and sauté until golden.
# 2. Add ginger-garlic paste and green chilies, cooking for another minute.
# 3. Add tomatoes and cook until soft. Stir in coriander powder, cumin powder, and salt.
# 4. Add chickpeas and a little water if needed. Simmer for 10-15 minutes.
# 5. Stir in garam masala and garnish with cilantro. Serve with rice or roti.
#
# ### 3. **Palak Paneer (Spinach and Cottage Cheese)**
#
# **Ingredients:**
# - 250g paneer, cubed
# - 4 cups spinach, blanched
# - 1 onion, chopped
# - 2 tomatoes, chopped
# - 2 green chilies
# - 1 teaspoon ginger-garlic paste
# - 1 teaspoon cumin seeds
# - 1 teaspoon garam masala
# - 2 tablespoons cream (optional)
# - Salt to taste
# - Oil for cooking
#
# **Instructions:**
# 1. Blend the blanched spinach with green chilies to a smooth paste.
# 2. Heat oil in a pan, add cumin seeds, and sauté onions until golden.
# 3. Add ginger-garlic paste and tomatoes, cooking until soft.
# 4. Stir in the spinach paste and cook for a few minutes. Add salt and garam masala.
# 5. Add paneer cubes and cook for another 5 minutes. Stir in cream if using.
# 6. Serve with naan or rice.
#
# ### 4. **Biryani (Spiced Rice Dish)**
#
# **Ingredients:**
# - 2 cups basmati rice
# - 500g chicken or vegetables
# - 1 onion, sliced
# - 2 tomatoes, chopped
# - 1 cup yogurt
# - 2-3 green chilies
# - 1 teaspoon ginger-garlic paste
# - Whole spices (bay leaf, cloves, cardamom, cinnamon)
# - 1 teaspoon biryani masala
# - Fresh cilantro and mint for garnish
# - Oil for cooking
#
# **Instructions:**
# 1. Soak basmati rice for 30 minutes and drain.
# 2. Heat oil in a pot, add whole spices, and sauté onions until golden.
# 3. Add ginger-garlic paste, green chilies, and chicken/vegetables. Cook until browned.
# 4. Stir in tomatoes and yogurt, cooking until the mixture thickens.
# 5. Add rice and enough water to cover. Bring to a boil, then reduce heat, cover, and cook until rice is done.
# 6. Garnish with cilantro and mint. Serve with raita.
#
# ### Tips:
# - Adjust spices according to your taste.
# - Serve with sides like naan, rice, or raita (yogurt sauce).
# - Enjoy the cooking process and feel free to experiment!
#
# Let me know if you need more recipes or specific instructions!Sure! Here are the vegetarian adaptations for the Indian dishes you mentioned, along with alternative ingredients and preparation methods:
#
# ### 1. **Vegetarian Butter Chicken (Murgh Makhani)**
#
# **Ingredients:**
# - 500g paneer or tofu, cut into pieces (as a substitute for chicken)
# - 1 cup yogurt
# - 2 tablespoons lemon juice
# - 2 teaspoons garam masala
# - 1 teaspoon turmeric
# - 1 teaspoon chili powder
# - 2 tablespoons butter or ghee
# - 1 onion, finely chopped
# - 2 cloves garlic, minced
# - 1-inch ginger, grated
# - 1 cup tomato puree
# - 1 cup cream (or coconut cream for a dairy-free option)
# - Salt to taste
# - Fresh cilantro for garnish
#
# **Instructions:**
# 1. Marinate the paneer or tofu in yogurt, lemon juice, garam masala, turmeric, and chili powder for at least 1 hour (or overnight).
# 2. In a pan, melt butter or ghee and sauté onions until golden. Add garlic and ginger, cooking for another minute.
# 3. Add the marinated paneer or tofu and cook until browned.
# 4. Stir in tomato puree and simmer for 15 minutes.
# 5. Add cream (or coconut cream) and salt, cooking for another 5 minutes.
# 6. Garnish with cilantro and serve with naan or rice.
#
# ### 2. **Chana Masala (Chickpea Curry)**
#
# This recipe is already vegetarian! No changes needed.
#
# ### 3. **Palak Paneer (Spinach and Cottage Cheese)**
#
# **Ingredients:**
# - 250g paneer, cubed (you can also use tofu as a substitute)
# - 4 cups spinach, blanched
# - 1 onion, chopped
# - 2 tomatoes, chopped
# - 2 green chilies
# - 1 teaspoon ginger-garlic paste
# - 1 teaspoon cumin seeds
# - 1 teaspoon garam masala
# - 2 tablespoons cream (optional, or use coconut cream for a dairy-free option)
# - Salt to taste
# - Oil for cooking
#
# **Instructions:**
# 1. Blend the blanched spinach with green chilies to a smooth paste.
# 2. Heat oil in a pan, add cumin seeds, and sauté onions until golden.
# 3. Add ginger-garlic paste and tomatoes, cooking until soft.
# 4. Stir in the spinach paste and cook for a few minutes. Add salt and garam masala.
# 5. Add paneer cubes (or tofu) and cook for another 5 minutes. Stir in cream if using.
# 6. Serve with naan or rice.
#
# ### 4. **Vegetable Biryani**
#
# **Ingredients:**
# - 2 cups basmati rice
# - 500g mixed vegetables (like carrots, peas, and bell peppers) instead of chicken
# - 1 onion, sliced
# - 2 tomatoes, chopped
# - 1 cup yogurt
# - 2-3 green chilies
# - 1 teaspoon ginger-garlic paste
# - Whole spices (bay leaf, cloves, cardamom, cinnamon)
# - 1 teaspoon biryani masala
# - Fresh cilantro and mint for garnish
# - Oil for cooking
#
# **Instructions:**
# 1. Soak basmati rice for 30 minutes and drain.
# 2. Heat oil in a pot, add whole spices, and sauté onions until golden.
# 3. Add ginger-garlic paste, green chilies, and mixed vegetables. Cook until the vegetables are slightly tender.
# 4. Stir in tomatoes and yogurt, cooking until the mixture thickens.
# 5. Add rice and enough water to cover. Bring to a boil, then reduce heat, cover, and cook until rice is done.
# 6. Garnish with cilantro and mint. Serve with raita.
#
# ### Tips:
# - Adjust spices according to your taste.
# - Serve with sides like naan, rice, or raita (yogurt sauce).
# - Enjoy the cooking process and feel free to experiment!
#
# Let me know if you need more recipes or specific instructions!
# AIMessageChunk(content='Sure! Here are the vegetarian adaptations for the Indian dishes you mentioned, along with alternative ingredients and preparation methods:\n\n### 1. **Vegetarian Butter Chicken (Murgh Makhani)**\n\n**Ingredients:**\n- 500g paneer or tofu, cut into pieces (as a substitute for chicken)\n- 1 cup yogurt\n- 2 tablespoons lemon juice\n- 2 teaspoons garam masala\n- 1 teaspoon turmeric\n- 1 teaspoon chili powder\n- 2 tablespoons butter or ghee\n- 1 onion, finely chopped\n- 2 cloves garlic, minced\n- 1-inch ginger, grated\n- 1 cup tomato puree\n- 1 cup cream (or coconut cream for a dairy-free option)\n- Salt to taste\n- Fresh cilantro for garnish\n\n**Instructions:**\n1. Marinate the paneer or tofu in yogurt, lemon juice, garam masala, turmeric, and chili powder for at least 1 hour (or overnight).\n2. In a pan, melt butter or ghee and sauté onions until golden. Add garlic and ginger, cooking for another minute.\n3. Add the marinated paneer or tofu and cook until browned.\n4. Stir in tomato puree and simmer for 15 minutes.\n5. Add cream (or coconut cream) and salt, cooking for another 5 minutes.\n6. Garnish with cilantro and serve with naan or rice.\n\n### 2. **Chana Masala (Chickpea Curry)**\n\nThis recipe is already vegetarian! No changes needed.\n\n### 3. **Palak Paneer (Spinach and Cottage Cheese)**\n\n**Ingredients:**\n- 250g paneer, cubed (you can also use tofu as a substitute)\n- 4 cups spinach, blanched\n- 1 onion, chopped\n- 2 tomatoes, chopped\n- 2 green chilies\n- 1 teaspoon ginger-garlic paste\n- 1 teaspoon cumin seeds\n- 1 teaspoon garam masala\n- 2 tablespoons cream (optional, or use coconut cream for a dairy-free option)\n- Salt to taste\n- Oil for cooking\n\n**Instructions:**\n1. Blend the blanched spinach with green chilies to a smooth paste.\n2. Heat oil in a pan, add cumin seeds, and sauté onions until golden.\n3. Add ginger-garlic paste and tomatoes, cooking until soft.\n4. Stir in the spinach paste and cook for a few minutes. Add salt and garam masala.\n5. Add paneer cubes (or tofu) and cook for another 5 minutes. Stir in cream if using.\n6. Serve with naan or rice.\n\n### 4. **Vegetable Biryani**\n\n**Ingredients:**\n- 2 cups basmati rice\n- 500g mixed vegetables (like carrots, peas, and bell peppers) instead of chicken\n- 1 onion, sliced\n- 2 tomatoes, chopped\n- 1 cup yogurt\n- 2-3 green chilies\n- 1 teaspoon ginger-garlic paste\n- Whole spices (bay leaf, cloves, cardamom, cinnamon)\n- 1 teaspoon biryani masala\n- Fresh cilantro and mint for garnish\n- Oil for cooking\n\n**Instructions:**\n1. Soak basmati rice for 30 minutes and drain.\n2. Heat oil in a pot, add whole spices, and sauté onions until golden.\n3. Add ginger-garlic paste, green chilies, and mixed vegetables. Cook until the vegetables are slightly tender.\n4. Stir in tomatoes and yogurt, cooking until the mixture thickens.\n5. Add rice and enough water to cover. Bring to a boil, then reduce heat, cover, and cook until rice is done.\n6. Garnish with cilantro and mint. Serve with raita.\n\n### Tips:\n- Adjust spices according to your taste.\n- Serve with sides like naan, rice, or raita (yogurt sauce).\n- Enjoy the cooking process and feel free to experiment!\n\nLet me know if you need more recipes or specific instructions!')

# %%
# Out:
# In the realm where code takes flight,
# Python dances, pure delight.
# With syntax clear, like morning dew,
# It whispers logic, fresh and new.
#
# Indentations, a gentle guide,
# In its embrace, complexities slide.
# From data frames to webs so grand,
# A versatile friend, at your command.
#
# Libraries bloom, like flowers in spring,
# NumPy, Pandas—oh, the joy they bring!
# In every loop, a story unfolds,
# With Python's charm, the future's bold.
#
# So here’s to the serpent, sleek and wise,
# In lines of code, where magic lies.
# With every script, a world to create,
# In Python's arms, we innovate.This poem celebrates the programming language Python in a vibrant and imaginative manner. Through the use of metaphor and imagery, the poet personifies Python as a graceful dancer and a wise serpent, highlighting its elegance and versatility in the realm of coding.
#
# ### Themes:
#
# 1. **Creativity and Innovation**: The poem suggests that programming, particularly with Python, is not just a technical endeavor but a creative process. Phrases like "With every script, a world to create" evoke the idea that coding can lead to new ideas and innovations, much like an artist creating a masterpiece.
#
# 2. **Simplicity and Clarity**: The opening lines emphasize the clarity of Python’s syntax, comparing it to "morning dew." This suggests that Python is approachable and user-friendly, which is particularly appealing to both novice and experienced programmers alike. The mention of “indentations” as a “gentle guide” reinforces this theme of simplicity in navigating complex tasks.
#
# 3. **Community and Collaboration**: The poem references Python’s libraries, such as NumPy and Pandas, symbolizing the extensive community and resources available to developers. These libraries are depicted as blooming flowers, suggesting growth and the sharing of knowledge within the programming community.
#
# 4. **Empowerment through Technology**: The notion that “Python’s charm” leads to a “bold future” speaks to the empowerment that comes with mastering such a versatile tool. The poem implies that Python enables individuals to tackle complex problems and create impactful solutions, emphasizing the transformative power of technology.
#
# 5. **Nature and Technology**: The comparison of coding elements to natural imagery—“libraries bloom, like flowers in spring”—highlights the harmony between the organic world and the digital realm. This metaphor suggests that coding, much like nature, can be both intricate and beautiful.
#
# ### Conclusion:
#
# Overall, the poem is a joyful ode to Python, encapsulating its elegance, user-friendliness, and the vast possibilities it offers to coders. By intertwining themes of creativity, clarity, community, empowerment, and the relationship between nature and technology, the poem elevates programming from a mere technical task to a rich, artistic experience.content='This poem celebrates the programming language Python in a vibrant and imaginative manner. Through the use of metaphor and imagery, the poet personifies Python as a graceful dancer and a wise serpent, highlighting its elegance and versatility in the realm of coding.\n\n### Themes:\n\n1. **Creativity and Innovation**: The poem suggests that programming, particularly with Python, is not just a technical endeavor but a creative process. Phrases like "With every script, a world to create" evoke the idea that coding can lead to new ideas and innovations, much like an artist creating a masterpiece.\n\n2. **Simplicity and Clarity**: The opening lines emphasize the clarity of Python’s syntax, comparing it to "morning dew." This suggests that Python is approachable and user-friendly, which is particularly appealing to both novice and experienced programmers alike. The mention of “indentations” as a “gentle guide” reinforces this theme of simplicity in navigating complex tasks.\n\n3. **Community and Collaboration**: The poem references Python’s libraries, such as NumPy and Pandas, symbolizing the extensive community and resources available to developers. These libraries are depicted as blooming flowers, suggesting growth and the sharing of knowledge within the programming community.\n\n4. **Empowerment through Technology**: The notion that “Python’s charm” leads to a “bold future” speaks to the empowerment that comes with mastering such a versatile tool. The poem implies that Python enables individuals to tackle complex problems and create impactful solutions, emphasizing the transformative power of technology.\n\n5. **Nature and Technology**: The comparison of coding elements to natural imagery—“libraries bloom, like flowers in spring”—highlights the harmony between the organic world and the digital realm. This metaphor suggests that coding, much like nature, can be both intricate and beautiful.\n\n### Conclusion:\n\nOverall, the poem is a joyful ode to Python, encapsulating its elegance, user-friendliness, and the vast possibilities it offers to coders. By intertwining themes of creativity, clarity, community, empowerment, and the relationship between nature and technology, the poem elevates programming from a mere technical task to a rich, artistic experience.'
